# %% [markdown]
# ### Binary search tree

# %% [markdown]
# ![Screenshot%202026-07-29%20021005.png](attachment:Screenshot%202026-07-29%20021005.png)

# %% [markdown]
# on left we have keys before jadhesh and on right we have keys after jadhesh.
# biraj < jadesh so it lies on left. sonaksh > jadhesh so lies on right

# %% [markdown]
# Terms: nodes, root ,branches, leaves

# %% [markdown]
# ![Screenshot%202026-07-29%20022809.png](attachment:Screenshot%202026-07-29%20022809.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Balanced BST have time complexity O(height)= O(logn) to insert ,find and update

# %% [markdown]
# Binary tree is used in file system to look up for file.(B+ tree where each node can have more than 2 child)

# %%
#
